# %% [markdown]
# Next steps:
# - understand PATH and why serial import not working
# - get data collection working
# - set up github repo with documentation
# - test with esp32 device
# - Get reset button and start stop switch into circuit
# - message adam w/ current version and plans for simplified all py data collection method

# %%
import serial
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import serial
#
# ModuleNotFoundError: No module named 'serial'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("data.csv")

time = np.array(df["Time (s)"])
V = np.array(df["Voltage (V)"])
R = np.array(df["Red"])
G = np.array(df["Green"])
B = np.array(df["Blue"])

# %%
df.head()
# Out:
#    Time (s)  Voltage (V)  Red  Green  Blue
# 0         0         2.14  102     88    52
# 1         1         1.54  102     89    52
# 2         2         1.42  102     88    52
# 3         3         1.42   91    100    66
# 4         4         1.41  125     96    62

# %%
TrialName = "Testing 1/19"

# %%
fig, axs = plt.subplots(3, 1, sharex = 'col', figsize = (10,10))

axs[0].plot(time, R, color='red', label='Red')
axs[0].plot(time, G, color='green', label = 'Green')
axs[0].plot(time, B, color='blue', label = 'Blue')
axs[0].set_xlim(0)
axs[0].set_ylim(0,180)
axs[0].set_xlabel("Time (s)")
axs[0].set_ylabel("RGB Magnitude")
#axs[0].set_title(f"RGB Results [{TrialName}]")
axs[0].legend()

axs[1].plot(time, V, label = 'Voltage', color='purple')
axs[1].set_xlabel("Time (s)")
axs[1].set_ylabel("Voltage (V)")
#axs[1].set_title(f"Voltage Results [{TrialName}]")
axs[1].legend()

ax1 = axs[2]
ax2 = ax1.twinx()

# Copy RGB lines from subplot 0
for line in axs[0].lines:
    ax1.plot(
        line.get_xdata(),
        line.get_ydata(),
        color=line.get_color(),
        label=line.get_label()
    )

ax1.set_ylabel('RGB Magnitude [Max 180]')
ax1.set_ylim(0, 180)

# Copy Voltage line from subplot 1
for line in axs[1].lines:
    ax2.plot(
        line.get_xdata(),
        line.get_ydata(),
        color=line.get_color(),
        label=line.get_label()
    )

ax2.set_ylabel('Voltage (V)')
ax2.set_xlabel('Time (s)')

# Combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')
axs[2].set_figsize(10, 20)

# ax1 = axs[2]

# # Plot RGB data
# ax1.plot(time, R, color='red', label='Red')
# ax1.plot(time, G, color='green', label = 'Green')
# ax1.plot(time, B, color='blue', label = 'Blue')
# ax1.set_ylabel('RGB Magnitude [Max 180]')
# #ax1.set_xlabel("Time (s)")
# ax1.set_ylim(0, 180)

# # Plot voltage data
# ax2 = ax1.twinx()
# ax2.plot(time, V, color='purple', label='Voltage')
# ax2.set_xlabel('Time (s)')
# ax2.set_ylabel('Voltage (V)')
# axs[2].legend()

# plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 50
#      48 lines2, labels2 = ax2.get_legend_handles_labels()
#      49 ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')
# ---> 50 axs[2].set_figsize(10, 20)
#
# AttributeError: 'Axes' object has no attribute 'set_figsize'

# %%
plt.plot(time, R, color='red', label='Red')
plt.plot(time, G, color='green', label = 'Green')
plt.plot(time, B, color='blue', label = 'Blue')

plt.ylim(0,180)

plt.xlabel("Time (s)")
plt.ylabel("RGB Magnitude")
plt.title(f"RGB Results [{TrialName}]")
plt.legend()

# %%
plt.plot(t, V, label = 'Voltage', color='purple')
plt.xlabel("Time (s)")
plt.ylabel("Voltage (V)")
plt.title(f"Voltage Results [{TrialName}]")
plt.legend()

# %%
fig, ax1 = plt.subplots()

# Plot RGB data
ax1.plot(time, R, color='red', label='Red')
ax1.plot(time, G, color='green', label = 'Green')
ax1.plot(time, B, color='blue', label = 'Blue')
ax1.set_ylabel('RGB Magnitude [Max 180]')
ax1.set_xlabel("Time (s)")
ax1.set_ylim(0, 180)


# Plot voltage data
ax2 = ax1.twinx()
ax2.plot(time, V, color='purple', label='Voltage')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Voltage (V)')

#title and saving
Title = TrialName
plt.title(Title)
plt.savefig(f"Plots/{Title}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 21
#      19 Title = TrialName
#      20 plt.title(Title)
# ---> 21 plt.savefig(f"Plots/{Title}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1243, in savefig(*args, **kwargs)
#    1240 fig = gcf()
#    1241 # savefig default implementation has no return, so mypy is unhappy
#    1242 # presumably this is here because subclasses can return?
# -> 1243 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# ...
